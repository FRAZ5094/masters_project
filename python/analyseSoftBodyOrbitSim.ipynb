# %%
import matplotlib.pyplot as plt
import numpy as np
from analysisFunctions import importOrbitData, calculateKeplerFromData

# %%
data = importOrbitData("sat_test_no_light_soft.txt")

kepler = calculateKeplerFromData(data)
# Out:
# 100%|██████████| 1052/1052 [00:00<00:00, 195715.58it/s]

# %%
plt.rcParams["axes.formatter.useoffset"]=False
plt.plot(data["t"],kepler["e"])
